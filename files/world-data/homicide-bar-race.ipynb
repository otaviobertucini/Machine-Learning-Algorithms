# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import seaborn as sns

# visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('/home/otavio/ml/datasets/world-data/homicides.csv')

# %%
data = data.rename(columns={'Intentional homicides (per 100,000 people) (per 100,000 people)': 'Rate'})

# %%
countries = pd.read_csv('/home/otavio/ml/datasets/utils/countries.csv')

# %%
data = data.merge(countries, how='left', left_on='Entity', right_on='Name')

# %%
new = data.pivot_table(columns='Year', values='Rate', index=['PT', 'ImageURL'])

# %%
new
# Out:
# Year                                                                   1995  \
# PT            ImageURL
# Afeganistão   https://upload.wikimedia.org/wikipedia/commons/...        NaN
# Albânia       https://upload.wikimedia.org/wikipedia/commons/...   6.685552
# Alemanha      https://upload.wikimedia.org/wikipedia/en/b/ba/...   1.716111
# Andorra       https://upload.wikimedia.org/wikipedia/commons/...        NaN
# Angola        https://upload.wikimedia.org/wikipedia/commons/...        NaN
# ...                                                                     ...
# Zâmbia        https://upload.wikimedia.org/wikipedia/commons/...        NaN
# cabo Verde    https://upload.wikimedia.org/wikipedia/commons/...        NaN
# África do Sul https://upload.wikimedia.org/wikipedia/commons/...  64.916527
# Áustria       https://upload.wikimedia.org/wikipedia/commons/...   1.033315
# Índia         https://upload.wikimedia.org/wikipedia/en/4/41/...   4.366263
#
# ...

# %%
new.to_csv('out.csv')
