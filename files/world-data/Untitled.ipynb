# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rn
import seaborn as sns

# visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data1 = pd.read_csv('/home/otavio/ml/datasets/world-data/health/death/annual-number-of-deaths-by-cause.csv')

# %%
data1
# Out:
#            Entity Code  Year Execution  Meningitis (deaths)  \
# 0     Afghanistan  AFG  1990       NaN          6469.977091
# 1     Afghanistan  AFG  1991       NaN          6347.158764
# 2     Afghanistan  AFG  1992       NaN          6659.741428
# 3     Afghanistan  AFG  1993       NaN          8068.386263
# 4     Afghanistan  AFG  1994       NaN          9432.845127
# ...           ...  ...   ...       ...                  ...
# 6681     Zimbabwe  ZWE  2013       NaN          1820.090331
# 6682     Zimbabwe  ZWE  2014       NaN          1769.993458
# 6683     Zimbabwe  ZWE  2015       NaN          1728.691503
# 6684     Zimbabwe  ZWE  2016       NaN          1703.437894
# 6685     Zimbabwe  ZWE  2017       NaN          1677.007331
#
#       Lower respiratory infections (deaths)  \
# 0                              22836.912346
# 1                              22325.633931
# 2                              23205.280750
# 3                              28229.715397
# ...

# %%
data = data1[data1['Year'] == 2017]
data
# Out:
#                           Entity      Code  Year Execution  \
# 27                   Afghanistan       AFG  2017       NaN
# 55                       Albania       ALB  2017       NaN
# 83                       Algeria       DZA  2017       NaN
# 111               American Samoa       ASM  2017       NaN
# 139         Andean Latin America       NaN  2017       NaN
# ...                          ...       ...   ...       ...
# 6545  Western Sub-Saharan Africa       NaN  2017       NaN
# 6573                       World  OWID_WRL  2017       NaN
# 6611                       Yemen       YEM  2017       NaN
# 6657                      Zambia       ZMB  2017       NaN
# 6685                    Zimbabwe       ZWE  2017       NaN
#
#       Meningitis (deaths)  Lower respiratory infections (deaths)  \
# 27            6588.668300                           2.143116e+04
# 55              18.606850                           3.816531e+02
# ...
