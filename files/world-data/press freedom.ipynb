# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import seaborn as sns

# visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('/home/otavio/ml/datasets/world-data/economic_freedom/press_freedom.csv', usecols=['Rank2020', 'EN_country', 'Score A', 'Sco Exa', 'Score 2020', 'Progression RANK'])

# %%
data = data.sort_values('Rank2020', ascending=True)

# %%
cou = pd.read_csv('/home/otavio/ml/datasets/utils/countries.csv')

# %%
data = data.merge(cou, how='left', left_on='EN_country', right_on='Name')
data
# Out:
#      Rank2020                             EN_country Score A     Sco Exa  \
# 0           1                                 Norway    7,84           0
# 1           2                                Finland    7,93           0
# 2           3                                Denmark    8,13           0
# 3           4                                 Sweden    9,25           0
# 4           5                            Netherlands    9,96           0
# ..        ...                                    ...     ...         ...
# 175       176                               Djibouti   76,73  6,93147181
# 176       177                                  China   76,68  80,4334217
# 177       178                                Eritrea    83,5  72,3561914
# 178       179                           Turkmenistan   85,44           0
# 179       180  Democratic People's Republic of Korea   85,82  51,9295685
#
#     Score 2020  Progression RANK  Index  \
# 0         7,84                 0  164.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 180 entries, 0 to 179
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rank2020          180 non-null    int64
#  1   EN_country        180 non-null    object
#  2   Score A           180 non-null    object
#  3   Sco Exa           180 non-null    object
#  4   Score 2020        180 non-null    object
#  5   Progression RANK  180 non-null    int64
#  6   Index             172 non-null    float64
#  7   Name              172 non-null    object
#  8   Code              170 non-null    object
#  9   PT                172 non-null    object
#  10  label             180 non-null    object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 16.9+ KB

# %%
data['label'] = data['PT'] + ' (' + data['Rank2020'].astype(str) + 'º)'
data
# Out:
#      Rank2020                             EN_country Score A     Sco Exa  \
# 0           1                                 Norway    7,84           0
# 1           2                                Finland    7,93           0
# 2           3                                Denmark    8,13           0
# 3           4                                 Sweden    9,25           0
# 4           5                            Netherlands    9,96           0
# ..        ...                                    ...     ...         ...
# 175       176                               Djibouti   76,73  6,93147181
# 176       177                                  China   76,68  80,4334217
# 177       178                                Eritrea    83,5  72,3561914
# 178       179                           Turkmenistan   85,44           0
# 179       180  Democratic People's Republic of Korea   85,82  51,9295685
#
#     Score 2020  Progression RANK  Index  \
# 0         7,84                 0  164.0
# ...

# %%
f10 = data[:10]
f10.to_csv('f10.csv')

# %%
f20 = data[10:20]
f20.to_csv('f20.csv')

# %%
f100 = data[100:110]
f100.to_csv('f100.csv')

# %%
fminus = data[-10:]
fminus
fminus.to_csv('fminus.csv')
