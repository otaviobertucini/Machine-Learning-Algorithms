# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import seaborn as sns

# visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('/home/otavio/ml/datasets/world-data/migration/migration.csv', encoding = "ISO-8859-1")

# %%
for c in data.columns:
    if(c == 'Country Name'):
        continue
    if(int(c) % 5 != 0):
        del data[c]

# %%
data = data.dropna()
data
# Out:
#      Country Name      1960      1965      1970      1975      1980  \
# 0           Aruba    7893.0    7677.0    7466.0    7262.0    7063.0
# 1     Afghanistan   46468.0   49535.0   53051.0   57043.0   59021.0
# 2          Angola  122089.0   77075.0   48657.0   30717.0   89891.0
# 3         Albania   48901.0   51409.0   54045.0   56816.0   59730.0
# 4         Andorra    2497.0    6983.0   13446.0   18623.0   25792.0
# ..            ...       ...       ...       ...       ...       ...
# 258         Samoa    3430.0    3442.0    3373.0    3742.0    4347.0
# 260   Yemen, Rep.  159146.0  177076.0  197025.0  219222.0  259374.0
# 261  South Africa  927656.0  945162.0  961496.0  962371.0  983303.0
# 262        Zambia  360835.0  325507.0  303465.0  297072.0  278798.0
# 263      Zimbabwe  387173.0  448754.0  499069.0  484678.0  470728.0
#
#           1985       1990       1995       2000       2005       2010  \
# 0       9860.0    14444.0    22274.0    30104.0    32540.0    34327.0
# ...

# %%
data = data.sort_values('2015', ascending=False)
countries = pd.read_csv('/home/otavio/ml/datasets/utils/countries.csv', encoding = "utf-8")
data = data.merge(countries, how='inner', left_on='Country Name', right_on='English')
data = data.head(50)
data
# Out:
#             Country Name        1960        1965        1970        1975  \
# 0          United States  10825599.0  11354439.0  11973787.0  13991349.0
# 1           Saudi Arabia     63389.0    155823.0    356996.0    928827.0
# 2         United Kingdom   1661888.0   2541943.0   2945896.0   3147977.0
# 3   United Arab Emirates      2194.0     25981.0     65827.0    312400.0
# 4                 Canada   2766304.0   3020552.0   3251353.0   3517845.0
# 5                 France   3507213.0   4447230.0   5210336.0   5571664.0
# 6              Australia   1698085.0   2054727.0   2456522.0   2659453.0
# 7                  Spain    210897.0    272201.0    355727.0    465542.0
# 8                  Italy    459553.0    629595.0    862556.0   1006374.0
# 9                  India   9410535.0   9350557.0   9181520.0   9011238.0
# 10              Thailand    484839.0    409954.0    347394.0    344715.0
# 11              Pakistan   6350296.0   5698452.0   5105556.0   4574348.0
# ...

# %%
new
# Out:
# PT                                               Estados Unidos  \
# Country Name                                      United States
# 1960                                                1.08256e+07
# 1965                                                1.13544e+07
# 1970                                                1.19738e+07
# 1975                                                1.39913e+07
# 1980                                                1.63644e+07
# 1985                                                1.94917e+07
# 1990                                                 2.3251e+07
# 1995                                                2.84511e+07
# 2000                                                3.48141e+07
# 2005                                                3.92583e+07
# 2010                                                4.41836e+07
# 2015                                                4.66271e+07
# index                                                       168
# ...

# %%
# new.to_csv('imi.csv')
data.to_csv('data.csv', index=False)
