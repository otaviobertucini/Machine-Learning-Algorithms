# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import seaborn as sns

# visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('/home/otavio/ml/datasets/world-data/life-expectancy.csv')

# %%
countries = pd.read_csv('/home/otavio/ml/datasets/utils/countries.csv')
data = data.merge(countries, how='left', left_on='Entity', right_on='Name')

# %%
# data = data[data['Year'] == 2016]
data = data[data['SubRegion'] == 'South America']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 684 entries, 342 to 13461
# Data columns (total 10 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Entity                                           684 non-null    object
#  1   Code_x                                           684 non-null    object
#  2   Year                                             684 non-null    int64
#  3   Life expectancy at birth, total (years) (years)  684 non-null    float64
#  4   Region                                           684 non-null    object
#  5   SubRegion                                        684 non-null    object
#  6   Name                                             684 non-null    object
#  7   Code_y                                           684 non-null    object
#  8   PT                                               684 non-null    object
# ...

# %%
data = data.sort_values('Life expectancy at birth, total (years) (years)', ascending=False).reset_index()

# %%
data['Label'] = data['PT'] + ' (' + (data.index + 1).astype(str, copy=False) + 'º)'

# %%
data
# Out:
#      index   Entity Code_x  Year  \
# 0     2244    Chile    CHL  2016
# 1     2243    Chile    CHL  2015
# 2     2242    Chile    CHL  2014
# 3     2241    Chile    CHL  2013
# 4     2240    Chile    CHL  2012
# ..     ...      ...    ...   ...
# 679   1222  Bolivia    BOL  1964
# 680   1221  Bolivia    BOL  1963
# 681   1220  Bolivia    BOL  1962
# 682   1219  Bolivia    BOL  1961
# 683   1218  Bolivia    BOL  1960
#
#      Life expectancy at birth, total (years) (years)    Region      SubRegion  \
# 0                                             79.522  Americas  South America
# 1                                             79.315  Americas  South America
# 2                                             79.117  Americas  South America
# 3                                             78.931  Americas  South America
# 4                                             78.758  Americas  South America
# ..                                               ...       ...            ...
# ...

# %%
brasil = data[data['PT'] == 'Brasil']

# %%
new = data.pivot_table(index='Year', columns='PT', values=['Life expectancy at birth, total (years) (years)'])
new
# Out:
#      Life expectancy at birth, total (years) (years)                          \
# PT                                         Argentina Bolívia  Brasil   Chile
# Year
# 1960                                          65.022  42.138  54.241  57.285
# 1961                                          65.141  42.454  54.754  57.682
# 1962                                          65.233  42.778  55.270  58.097
# 1963                                          65.311  43.110  55.785  58.533
# 1964                                          65.388  43.451  56.293  58.993
# 1965                                          65.481  43.800  56.794  59.479
# 1966                                          65.603  44.157  57.289  59.994
# 1967                                          65.760  44.523  57.776  60.536
# 1968                                          65.953  44.898  58.254  61.104
# 1969                                          66.184  45.280  58.717  61.696
# ...

# %%
new['SA'] = new.mean(axis=1)
# new.unstack().to_frame()
# br_sa = new[['Brasil', 'SA']]
# br_sa
new.to_csv('ehhe.csv')

# %%
# data.to_csv('out.csv', index=False)
