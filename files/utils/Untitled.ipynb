# %%
# data analysis and wrangling
import pandas as pd
import numpy as np

# %%
# https://www.kaggle.com/fernandol/countries-of-the-world#countries%20of%20the%20world.csv
world = pd.read_csv('/home/otavio/ml/datasets/utils/guerra/countries of the world.csv')

# %%
world
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# ...

# %%
world['Country'] = world['Country'].apply(lambda x: x.replace(' ', ''))

# %%
hdi = pd.read_csv('/home/otavio/ml/datasets/utils/guerra/hdi.csv')

# %%
hdi = hdi[['Country', '2018']]
hdi
# Out:
#                                                Country   2018
# 0                                          Afghanistan  0.496
# 1                                              Albania  0.791
# 2                                              Algeria  0.759
# 3                                              Andorra  0.857
# 4                                               Angola  0.574
# ..                                                 ...    ...
# 202                          Least Developed Countries  0.528
# 203                     Small Island Developing States  0.723
# 204  Organization for Economic Co-operation and Dev...  0.895
# 205                                              World  0.731
# 206                                                NaN    NaN
#
# [207 rows x 2 columns]

# %%
world = world.merge(hdi, on='Country', how='left')
world
# Out:
#            Country                               Region  Population  \
# 0      Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1          Albania  EASTERN EUROPE                          3581655
# 2          Algeria  NORTHERN AFRICA                        32930091
# 3    AmericanSamoa  OCEANIA                                   57794
# 4          Andorra  WESTERN EUROPE                            71201
# ..             ...                                  ...         ...
# 222       WestBank  NEAR EAST                               2460492
# 223  WesternSahara  NORTHERN AFRICA                          273008
# 224          Yemen  NEAR EAST                              21456188
# 225         Zambia  SUB-SAHARAN AFRICA                     11502010
# 226       Zimbabwe  SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# ...
