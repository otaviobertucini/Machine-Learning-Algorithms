# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rn
import seaborn as sns

# visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cou = pd.read_csv('/home/otavio/ml/datasets/utils/countries.csv')

# %%
flags = pd.read_csv('/home/otavio/ml/datasets/utils/flags.csv')

# %%
flags.drop('Images File Name', axis=1, inplace=True)

# %%
cou
# Out:
#      Index                                   Name Code               PT
# 0        0                            Afghanistan   AF      Afeganistão
# 1        1                          Aland Islands   AX      Ilhas Aland
# 2        2                                Albania   AL          Albânia
# 3        3                                Algeria   DZ          Argélia
# 4        4                         American Samoa   AS  Samoa Americana
# ..     ...                                    ...  ...              ...
# 249    249                                  Butan  NaN            Butão
# 250    250                                England  NaN       Inglaterra
# 251    251  Democratic People's Republic of Korea  NaN  Coréia do Norte
# 252    252                                Vietnam  NaN           Vietnã
# 253    253                                 Russia  NaN           Rússia
#
# [254 rows x 4 columns]

# %%
cou = cou.merge(flags, left_on='Name', right_on='Country')
cou
# Out:
#      Index         Name Code           PT      Country  \
# 0        0  Afghanistan   AF  Afeganistão  Afghanistan
# 1        2      Albania   AL      Albânia      Albania
# 2        3      Algeria   DZ      Argélia      Algeria
# 3        5      Andorra   AD      Andorra      Andorra
# 4        6       Angola   AO       Angola       Angola
# ..     ...          ...  ...          ...          ...
# 181    245        Yemen   YE        Iémen        Yemen
# 182    246       Zambia   ZM       Zâmbia       Zambia
# 183    247     Zimbabwe   ZW     Zimbábue     Zimbabwe
# 184    252      Vietnam  NaN       Vietnã      Vietnam
# 185    253       Russia  NaN       Rússia       Russia
#
#                                               ImageURL
# 0    https://upload.wikimedia.org/wikipedia/commons...
# 1    https://upload.wikimedia.org/wikipedia/commons...
# 2    https://upload.wikimedia.org/wikipedia/commons...
# 3    https://upload.wikimedia.org/wikipedia/commons...
# ...

# %%
cou.drop('Country', axis=1, inplace=True)

# %%
cou.drop('Index', axis=1, inplace=True)

# %%
cou
# Out:
#             Name Code           PT  \
# 0    Afghanistan   AF  Afeganistão
# 1        Albania   AL      Albânia
# 2        Algeria   DZ      Argélia
# 3        Andorra   AD      Andorra
# 4         Angola   AO       Angola
# ..           ...  ...          ...
# 181        Yemen   YE        Iémen
# 182       Zambia   ZM       Zâmbia
# 183     Zimbabwe   ZW     Zimbábue
# 184      Vietnam  NaN       Vietnã
# 185       Russia  NaN       Rússia
#
#                                               ImageURL
# 0    https://upload.wikimedia.org/wikipedia/commons...
# 1    https://upload.wikimedia.org/wikipedia/commons...
# 2    https://upload.wikimedia.org/wikipedia/commons...
# 3    https://upload.wikimedia.org/wikipedia/commons...
# 4    https://upload.wikimedia.org/wikipedia/commons...
# ..                                                 ...
# 181  https://upload.wikimedia.org/wikipedia/commons...
# 182  https://upload.wikimedia.org/wikipedia/commons...
# ...

# %%
cou.to_csv('countries.csv', index=False)
