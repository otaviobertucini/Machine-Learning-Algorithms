# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import seaborn as sns

# visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
exer = pd.read_csv('/home/otavio/ml/datasets/trends/exer.csv')
fig, ax = plt.subplots(figsize=(12, 10))
exer.plot(ax=ax)
plt.xticks([])
plt.yticks([])
ax.legend(loc='upper left', shadow=True, fontsize='xx-large')
fig.savefig('exer.png')

# %%
cor = pd.read_csv('/home/otavio/ml/datasets/trends/tedio.csv')
cor['coronavirus'] = cor['coronavirus'].apply(lambda x: int(x.replace('<', '')))
cor
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'coronavirus'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-6a1e509c42b0> in <module>
# ...

# %%
fig, ax = plt.subplots(figsize=(12, 10))
cor.plot(ax=ax)
plt.xticks([])
plt.yticks([])
ax.legend(loc='upper left', shadow=True, fontsize='xx-large')
fig.savefig('cor.png')

# %%
zoom = pd.read_csv('/home/otavio/ml/datasets/trends/zoom.csv')
fig, ax = plt.subplots(figsize=(12, 10))
zoom.plot(ax=ax)
plt.xticks([])
plt.yticks([])
ax.legend(loc='upper left', shadow=True, fontsize='xx-large')
fig.savefig('zoom.png')

# %%
tedio = pd.read_csv('/home/otavio/ml/datasets/trends/tedio.csv')
fig, ax = plt.subplots(figsize=(12, 10))
tedio.plot(ax=ax)
plt.xticks([])
plt.yticks([])
ax.legend(loc='upper left', shadow=True, fontsize='xx-large')
fig.savefig('tedio.png')

# %%
bar = pd.read_csv('/home/otavio/ml/datasets/trends/bar.csv')
fig, ax = plt.subplots(figsize=(12, 10))
bar.plot(ax=ax)
plt.xticks([])
plt.yticks([])
ax.legend(loc='upper left', shadow=True, fontsize='xx-large')
fig.savefig('bar.png')
