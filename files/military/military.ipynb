# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import seaborn as sns

# visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('/home/otavio/ml/datasets/World_Data/military/ex_gdp.csv', error_bad_lines=False)

# %%
data
# Out:
#      Country Name Country Code                   Indicator Name  \
# 0           Aruba          ABW  Military expenditure (% of GDP)
# 1     Afghanistan          AFG  Military expenditure (% of GDP)
# 2          Angola          AGO  Military expenditure (% of GDP)
# 3         Albania          ALB  Military expenditure (% of GDP)
# 4         Andorra          AND  Military expenditure (% of GDP)
# ..            ...          ...                              ...
# 259        Kosovo          XKX  Military expenditure (% of GDP)
# 260   Yemen, Rep.          YEM  Military expenditure (% of GDP)
# 261  South Africa          ZAF  Military expenditure (% of GDP)
# 262        Zambia          ZMB  Military expenditure (% of GDP)
# 263      Zimbabwe          ZWE  Military expenditure (% of GDP)
#
#         Indicator Code      1960      1961      1962      1963      1964  \
# 0    MS.MIL.XPND.GD.ZS       NaN       NaN       NaN       NaN       NaN
# ...

# %%
d2018 = data[data['2018'].notnull()]
d2018 = d2018.sort_values('2018', ascending=False).reset_index()

# %%
d2018.head(20)
# Out:
#                   Country Name      2018
# 0                 Saudi Arabia  8.774719
# 1                         Oman  8.171300
# 2                   Arab World  5.649372
# 3   Middle East & North Africa  5.475542
# 4                      Algeria  5.271414
# 5                       Kuwait  5.055532
# 6                      Lebanon  4.993891
# 7                      Armenia  4.778338
# 8                       Jordan  4.682529
# 9                       Israel  4.348101
# 10                    Pakistan  4.025736
# 11          Russian Federation  3.929511
# 12                     Ukraine  3.782803
# 13                  Azerbaijan  3.773694
# 14                     Bahrain  3.595485
# 15                  Uzbekistan  3.555483
# 16                     Namibia  3.349633
# 17                    Colombia  3.172560
# 18               United States  3.162865
# 19                   Singapore  3.143632

# %%
d2018 = d2018[['Country Name', '2018']]

# %%
to_csv = d2018.head(20)
to_csv.to_csv('out.csv', index=True)

# %%
d2018[d2018['Country Name'] == 'Brazil']
# Out:
#     Country Name      2018
# 101       Brazil  1.474902
