# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import seaborn as sns

# visualization
import matplotlib.pyplot as plt
# %matplotlib inline

from googletrans import Translator

# %%
data = pd.read_csv('/home/otavio/ml/datasets/utils/countries.csv')

# %%
def t(x):
    gt = Translator()
    return gt.translate(text=x, src='en', dest='pt').text

# %%
data['PT'] = data['English']
gt = Translator()
data['PT'] = data['PT'].apply(t)

# %%
data
# Out:
#      index      English Code  \
# 0        0  Afghanistan   AF
# 1        1      Albania   AL
# 2        2      Algeria   DZ
# 3        3      Andorra   AD
# 4        4       Angola   AO
# ..     ...          ...  ...
# 170    170   Uzbekistan   UZ
# 171    171      Vanuatu   VU
# 172    172        Yemen   YE
# 173    173       Zambia   ZM
# 174    174     Zimbabwe   ZW
#
#                                               ImageURL           PT
# 0    https://upload.wikimedia.org/wikipedia/commons...  Afeganistão
# 1    https://upload.wikimedia.org/wikipedia/commons...      Albânia
# 2    https://upload.wikimedia.org/wikipedia/commons...      Argélia
# 3    https://upload.wikimedia.org/wikipedia/commons...      Andorra
# 4    https://upload.wikimedia.org/wikipedia/commons...       Angola
# ..                                                 ...          ...
# 170  https://upload.wikimedia.org/wikipedia/commons...  Uzbequistão
# ...

# %%
data.to_csv('/home/otavio/ml/datasets/utils/countries.csv', index=False)
