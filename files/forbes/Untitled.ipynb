# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import seaborn as sns

# visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('/home/otavio/ml/datasets/forbes/forbes-2017.csv')

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
sectors = data['Sector'].value_counts(normalize=True)
sectors.to_csv('sectors.csv')

# %%
br = data[data['Country'] == 'Brazil'].head(50)
br[:10][['Company']].head(10).to_csv('br.csv')
# data['Sector'].unique()

# %%
gb = data.groupby('Sector')['Profits'].sum()
gb.sort_values().to_csv('profits.csv')

# %%
countries = pd.read_csv('/home/otavio/ml/datasets/utils/countries.csv')

# %%
data = data.merge(countries, how='left', right_on='Name', left_on='Country')
data
# Out:
#        Rank                  Company        Country    Sales  Profits  Assets  \
# 0         1                     ICBC          China  151.400   42.000  3473.2
# 1         2  China Construction Bank          China  134.200   35.000  3016.6
# 2         3       Berkshire Hathaway  United States  222.900   24.100   620.9
# 3         4           JPMorgan Chase  United States  102.500   24.200  2513.0
# 4         5              Wells Fargo  United States   97.600   21.900  1943.4
# ...     ...                      ...            ...      ...      ...     ...
# 1995   1996                BEKB-BCBE    Switzerland    0.555    0.131    27.9
# 1996   1997        Fastighets Balder         Sweden    0.630    0.639    10.2
# 1997   1998      Akamai Technologies  United States    2.300    0.316     4.4
# 1998   1999                Oita Bank          Japan    0.523    0.071    27.9
# 1999   2000            Tech Mahindra          India    4.200    0.469     3.6
#
# ...

# %%
data['PT'].value_counts(normalize=True)
# Out:
# Estados Unidos            0.299681
# Japão                     0.121679
# China                     0.106270
# Reino Unido               0.048353
# Coreia do Sul             0.034006
# França                    0.031350
# Índia                     0.030818
# Canadá                    0.030818
# Alemanha                  0.027099
# Suíça                     0.024442
# Austrália                 0.020723
# Itália                    0.014346
# Rússia                    0.014346
# Suécia                    0.013815
# Países Baixos             0.012752
# Espanha                   0.012221
# Irlanda                   0.010627
# Brasil                    0.010627
# Arábia Saudita            0.009033
# Cingapura                 0.009033
# México                    0.007970
# Tailândia                 0.007439
# Malásia                   0.007439
# Emirados Árabes Unidos    0.007439
# Peru                      0.006376
# Dinamarca                 0.006376
# África do Sul             0.005313
# ...
