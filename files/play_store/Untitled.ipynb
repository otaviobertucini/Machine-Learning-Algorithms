# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import seaborn as sns

from googletrans import Translator

# visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('/home/otavio/ml/datasets/play-store/googleplaystore.csv')
data = data.drop(['Android Ver', 'Current Ver', 'Last Updated'], axis=1)
data.info()
data = data[data['Type'].notna()]
data = data[data['Type'] != '0']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 847.1+ KB

# %%
d2 = data[data.groupby('Category')['App'].transform('size') > 300]
d2.Category.unique()
# Out:
# array(['BUSINESS', 'COMMUNICATION', 'FINANCE', 'HEALTH_AND_FITNESS',
#        'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL', 'PHOTOGRAPHY', 'SPORTS',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY'], dtype=object)

# %%
gt = Translator()
labels = d2.Category.unique()
labels = list(labels)
d = {}
for l in labels:
    d[l] = gt.translate(text=l.replace('_', ' '), src='en', dest='pt').text.upper()
d['BUSINESS'] = 'NEGÓCIOS'

# %%
d2['Category'] = d2['Category'].apply(lambda x: d[x])
d2['Category']
# Out:
# /home/otavio/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 187            NEGÓCIOS
# 188            NEGÓCIOS
# 189            NEGÓCIOS
# 190            NEGÓCIOS
# 191            NEGÓCIOS
#               ...
# 10835          NEGÓCIOS
# 10836           FAMÍLIA
# 10837           FAMÍLIA
# 10838            MÉDICO
# 10840    ESTILO DE VIDA
# Name: Category, Length: 7892, dtype: object

# %%
plt.figure(figsize=(11.25,5.625))
fig = sns.countplot(x=d2['Category'], palette="hls", orient='h')
fig.set_xticklabels(fig.get_xticklabels(), rotation=45, horizontalalignment='right')
fig.set(xlabel='Categoria', ylabel='Quantidade')
plt.tight_layout()
fig.get_figure().savefig('out.png')

# %%
d = {'Paid': 'Pago', 'Free': 'Gratuito'}
data['Type'] = data['Type'].apply(lambda x: d[x])
data['Type']
# Out:
# 0        Gratuito
# 1        Gratuito
# 2        Gratuito
# 3        Gratuito
# 4        Gratuito
#            ...
# 10836    Gratuito
# 10837    Gratuito
# 10838    Gratuito
# 10839    Gratuito
# 10840    Gratuito
# Name: Type, Length: 10839, dtype: object

# %%
plt.figure(figsize=(5,3))
fig = sns.countplot(x=data['Type'])
fig.set_xticklabels(fig.get_xticklabels(),rotation=90)
fig.set(xlabel='Categoria', ylabel='Quantidade')
plt.tight_layout()
fig.get_figure().savefig('out2.png')

# %%
d3 = data[data['Category'] == 'FAMILY']
d3['Installs'] = d3['Installs'].apply(lambda x: int(x.replace('+', '').replace(',', '')))
soma = d3['Installs'].sum()
soma
# Out:
# /home/otavio/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 10258263505

# %%
d3 = d3.sort_values('Installs')
d3.tail(20)
# Out:
#                                             App Category  Rating   Reviews  \
# 4229                     Where's My Water? Free   FAMILY     4.4   1372013
# 2216             Duolingo: Learn Languages Free   FAMILY     4.7   6294397
# 4257                     Cut the Rope FULL FREE   FAMILY     4.4   2122705
# 3930                                  Flow Free   FAMILY     4.3   1295293
# 2016                                     ROBLOX   FAMILY     4.5   4449910
# 3889                                    Netflix   FAMILY     4.4   5453997
# 10186                          Farm Heroes Saga   FAMILY     4.4   7615646
# 4247                            Talking Tom Cat   FAMILY     4.3   1838090
# 3975                                    Hay Day   FAMILY     4.5  10053186
# 3910                          My Talking Angela   FAMILY     4.5   9876369
# 4036   Minion Rush: Despicable Me Official Game   FAMILY     4.5  10214862
# 3987                               Clash Royale   FAMILY     4.6  23125280
# 6849                        Bubble Witch 2 Saga   FAMILY     4.3   2838064
# 2088                                     ROBLOX   FAMILY     4.5   4450855
# 4329                           Tom Loves Angela   FAMILY     4.1   1111915
# 2090   Minion Rush: Despicable Me Official Game   FAMILY     4.5  10216997
# 3994                           Candy Crush Saga   FAMILY     4.4  22419455
# 3888                             My Talking Tom   FAMILY     4.5  14885236
# 3879                                        Pou   FAMILY     4.3  10483141
# 5856                          Google Play Games   FAMILY     4.3   7168735
#
#                      Size    Installs      Type Price Content Rating  \
# 4229                  57M   100000000  Gratuito     0       Everyone
# 2216   Varies with device   100000000  Gratuito     0       Everyone
# 4257                  49M   100000000  Gratuito     0       Everyone
# 3930                  11M   100000000  Gratuito     0       Everyone
# 2016                  67M   100000000  Gratuito     0   Everyone 10+
# 3889   Varies with device   100000000  Gratuito     0           Teen
# 10186                 71M   100000000  Gratuito     0       Everyone
# 4247   Varies with device   100000000  Gratuito     0   Everyone 10+
# 3975                  94M   100000000  Gratuito     0       Everyone
# 3910                  99M   100000000  Gratuito     0       Everyone
# 4036   Varies with device   100000000  Gratuito     0   Everyone 10+
# 3987                  97M   100000000  Gratuito     0   Everyone 10+
# 6849   Varies with device   100000000  Gratuito     0       Everyone
# 2088                  67M   100000000  Gratuito     0   Everyone 10+
# 4329                  50M   100000000  Gratuito     0       Everyone
# 2090   Varies with device   100000000  Gratuito     0   Everyone 10+
# 3994                  74M   500000000  Gratuito     0       Everyone
# 3888   Varies with device   500000000  Gratuito     0       Everyone
# 3879                  24M   500000000  Gratuito     0       Everyone
# 5856   Varies with device  1000000000  Gratuito     0           Teen
#
#                              Genres
# 4229             Puzzle;Brain Games
# 2216            Education;Education
# 4257                         Puzzle
# 3930                         Puzzle
# 2016   Adventure;Action & Adventure
# 3889                  Entertainment
# 10186                        Casual
# 4247                         Casual
# 3975                         Casual
# 3910                         Casual
# 4036      Casual;Action & Adventure
# 3987                       Strategy
# 6849                         Casual
# 2088   Adventure;Action & Adventure
# 4329                  Entertainment
# 2090      Casual;Action & Adventure
# 3994                         Casual
# 3888                         Casual
# 3879                         Casual
# 5856                  Entertainment
