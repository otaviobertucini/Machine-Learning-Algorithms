# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rn
import seaborn as sns

# visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('/home/otavio/ml/datasets/dugs/prevalence-general.csv')

# %%
data = data[data['Drug Type'] == 'Cannabis']

# %%
data.columns
# Out:
# Index(['Drug Type', 'Country', 'Year', 'Best', 'High', 'Male', 'Female', 'Low',
#        'Age', 'Source', 'Method', 'Adjustment', 'Specific notes', 'Sub-region',
#        'Region'],
#       dtype='object')

# %%
data = data.sort_values(['Country', 'Year'], ascending=False)

# %%
res = data.groupby(['Country'], as_index=False).first()
res
# Out:
#                                 Country Drug Type  Year   Best   High   Male  \
# 0                           Afghanistan  Cannabis  2009   4.28   5.18   8.10
# 1                               Albania  Cannabis  2014   5.60    NaN  10.20
# 2                               Algeria  Cannabis  2010   0.52    NaN   1.06
# 3                             Argentina  Cannabis  2017   8.13    NaN  11.10
# 4                               Armenia  Cannabis  2003   3.50    NaN    NaN
# ..                                  ...       ...   ...    ...    ...    ...
# 118            United States of America  Cannabis  2018  19.40    NaN  22.20
# 119                             Uruguay  Cannabis  2018  14.60    NaN  17.80
# 120                          Uzbekistan  Cannabis  2003   4.20    NaN    NaN
# 121  Venezuela (Bolivarian Republic of)  Cannabis  2011   1.56    NaN    NaN
# 122                              Zambia  Cannabis  2004   9.50  15.60    NaN
#
#      Female   Low    Age                   Source Method Adjustment  \
# 0      0.20  3.37  15-64      UNODC/ Govt. Source    HHS        NaN
# 1      1.00   NaN  15-64                      ARQ    HHS       d, e
# 2      0.03   NaN    12+                      ARQ    HHS        NaN
# 3      5.46   NaN  15-64                      ARQ    HHS        NaN
# 4       NaN   NaN  15-64           UNODC Estimate    NaN        NaN
# ..      ...   ...    ...                      ...    ...        ...
# 118   16.80   NaN  15-64                      ARQ    HHS        NaN
# 119   11.50   NaN  15-65                      ARQ    HHS        NaN
# 120     NaN   NaN  15-64           UNODC Estimate    NaN          e
# 121     NaN   NaN  12-65        Government source    HHS       a, e
# 122     NaN  4.00  15-64  Govt; Academic Research     SS       d, e
#
#     Specific notes                            Sub-region    Region
# 0              NaN  Near and Middle East/South-West Asia      Asia
# 1    Cannabis herb                  South-Eastern Europe    Europe
# 2              NaN                          North Africa    Africa
# 3    Cannabis herb                         South America  Americas
# 4              NaN        Central Asia and Transcaucasia      Asia
# ..             ...                                   ...       ...
# 118  Cannabis herb                         North America  Americas
# 119  Cannabis herb                         South America  Americas
# 120            NaN        Central Asia and Transcaucasia      Asia
# 121            NaN                         South America  Americas
# 122            NaN                       Southern Africa    Africa
#
# [123 rows x 15 columns]

# %%
tops = countries['Year'].max()
tops
# Out:
# Country                             Year
# Afghanistan                         2005    2005
#                                     2009    2009
# Albania                             2006    2006
#                                     2014    2014
# Algeria                             2010    2010
#                                             ...
# Uzbekistan                          2003    2003
# Venezuela (Bolivarian Republic of)  2005    2005
#                                     2011    2011
# Zambia                              2003    2003
#                                     2004    2004
# Name: Year, Length: 339, dtype: int64
