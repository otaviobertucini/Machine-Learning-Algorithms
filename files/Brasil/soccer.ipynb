# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import seaborn as sns

# visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('https://query.data.world/s/ok7amqbjdegxmltbromkxkxwndcg4n')

# %%
data
# Out:
#      Confederation                   Stadium         City  \
# 0             UEFA       Stadiumi Besëlidhja        Lezhë
# 1             UEFA       Stadiumi Flamurtari        Vlorë
# 2             UEFA             Stadiumi Laçi         Laçi
# 3             UEFA      Stadiumi Niko Dovana       Durrës
# 4             UEFA  Stadiumi Selman Stërmasi       Tirana
# ...            ...                       ...          ...
# 2019          UEFA           Liberty Stadium      Swansea
# 2020          UEFA           Parc y Scarlets     Llanelli
# 2021          UEFA               Park Avenue  Aberystwyth
# 2022          UEFA      Principality Stadium      Cardiff
# 2023          UEFA         Racecourse Ground      Wrexham
#
#                          HomeTeams  Capacity  Country  IOC  Population
# 0                       Besëlidhja      7000  Albania  ALB     2876591
# 1                 Flamurtari Vlorë      8200  Albania  ALB     2876591
# ...

# %%
pop = data.groupby('Country')['Population'].max().to_frame().reset_index()
pop['perhab'] = pop['Country'].map(places) / pop['Population']
pop.sort_values('perhab', ascending=False, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-75c9a0f4c569> in <module>
#       1 pop = data.groupby('Country')['Population'].max().to_frame().reset_index()
#       2 places = data.groupby('Country')['Capacity'].sum().to_frame().reset_index()
# ----> 3 pop['perhab'] = pop['Country'].map(places) / pop['Population']
#       4 pop.sort_values('perhab', ascending=False, inplace=True)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    3628         dtype: object
#    3629         """
# -> 3630         new_values = super()._map_values(arg, na_action=na_action)
#    3631         return self._constructor(new_values, index=self.index).__finalize__(self)
#    3632
#
# ~/.local/lib/python3.6/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#    1104                 # be float64 as well
# ...

# %%
new_pop =

# %%
cou = pd.read_csv('/home/otavio/ml/datasets/utils/countries.csv')
cou
# Out:
#      Index                      Name   Code               PT
# 0        0               Afghanistan     AF      Afeganistão
# 1        1             Aland Islands     AX      Ilhas Aland
# 2        2                   Albania     AL          Albânia
# 3        3                   Algeria     DZ          Argélia
# 4        4            American Samoa     AS  Samoa Americana
# ..     ...                       ...    ...              ...
# 246    246                    Zambia     ZM           Zâmbia
# 247    247                  Zimbabwe     ZW         Zimbábue
# 248    248  United States of America     US   Estados Unidos
# 249    249                     Butan  Butão              NaN
# 250    250                   England    NaN       Inglaterra
#
# [251 rows x 4 columns]

# %%
new_pop = pop.merge(cou, left_on='Country', right_on='Name')

# %%
# new_pop.drop(['index', 'English', 'Code', 'Country'], axis=1, inplace=True)
new_pop.head(10).to_csv('perhab.csv')

# %%
places = data.groupby('Country')['Capacity'].sum().to_frame().reset_index()
places = places.merge(cou, left_on='Country', right_on='Name', how='left')

# %%
places.sort_values('Capacity', ascending=False, inplace=True)
places.head(10).to_csv('stad.csv')

# %%
brasil = data[data['Country'] == 'Brazil']
brasil = brasil[brasil['Stadium'] != 'Estádio Olímpico Monumental']
brasil['fullname'] = brasil['Stadium'] + ' (' + brasil['HomeTeams'] + ')'
brasil.sort_values('Capacity', inplace=True, ascending=False)
brasil.head(10).to_csv('bra.csv')

# %%
data['fullname'] = data['Stadium'] + ' (' + data['HomeTeams'] + ')'
data.sort_values('Capacity', inplace=True, ascending=False)
data.head(10).to_csv('mond.csv')
