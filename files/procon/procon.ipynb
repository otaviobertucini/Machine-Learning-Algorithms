# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import seaborn as sns

# visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
d12 = pd.read_csv('/home/otavio/ml/datasets/procon/reclamacoes-fundamentadas-sindec-2012.csv')
d13 = pd.read_csv('/home/otavio/ml/datasets/procon/reclamacoes-fundamentadas-sindec-2013.csv')
d14 = pd.read_csv('/home/otavio/ml/datasets/procon/reclamacoes-fundamentadas-sindec-2014.csv')
d15 = pd.read_csv('/home/otavio/ml/datasets/procon/reclamacoes-fundamentadas-sindec-2015.csv')
d16 = pd.read_csv('/home/otavio/ml/datasets/procon/reclamacoes-fundamentadas-sindec-2016.csv')

# %%
frames = [d12, d13, d14, d15, d16]
data = pd.concat(frames)
data
# Out:
#         AnoCalendario         DataArquivamento             DataAbertura  \
# 0                2012  2012-07-13 17:44:45.000  2009-09-17 10:48:42.000
# 1                2012  2012-07-13 17:37:19.000  2009-09-17 10:02:24.000
# 2                2012  2012-07-16 09:07:13.000  2009-09-17 11:36:47.000
# 3                2012  2012-12-10 09:05:09.000  2009-09-21 09:01:49.000
# 4                2012  2012-07-13 17:51:01.000  2009-09-18 17:32:22.000
# ...               ...                      ...                      ...
# 203481           2016  2016-08-24 10:19:29.000  2016-05-06 11:21:45.000
# 203482           2016  2016-10-27 09:19:09.000  2016-05-02 15:28:57.000
# 203483           2016  2016-09-21 09:11:21.000  2016-04-29 16:20:30.000
# 203484           2016  2016-08-16 10:58:52.000  2016-04-19 07:58:16.000
# 203485           2016  2016-09-21 09:44:57.000  2016-04-19 08:42:27.000
#
#         CodigoRegiao        Regiao  UF  \
# 0                  3       Sudeste  ES
# ...

# %%
most_companies = data['strNomeFantasia'].value_counts()
most_category = data['DescCNAEPrincipal'].value_counts()
most_desc = data['DescricaoAssunto'].value_counts()

# %%
most_companies.head(10)
# Out:
# BANCOS MÚLTIPLOS, COM CARTEIRA COMERCIAL                                                                   113385
# TELEFONIA MÓVEL CELULAR                                                                                     84400
# COMÉRCIO VAREJISTA ESPECIALIZADO DE ELETRODOMÉSTICOS E EQUIPAMENTOS DE ÁUDIO E VÍDEO                        67955
# SERVIÇOS DE TELEFONIA FIXA COMUTADA - STFC                                                                  60104
# LOJAS DE DEPARTAMENTOS OU MAGAZINES                                                                         35248
# FABRICAÇÃO DE FOGÕES, REFRIGERADORES E MÁQUINAS DE LAVAR E SECAR PARA USO DOMÉSTICO, PEÇAS E ACESSÓRIOS     31506
# COMÉRCIO VAREJISTA DE MÓVEIS                                                                                27662
# FABRICAÇÃO DE APARELHOS DE RECEPÇÃO, REPRODUÇÃO, GRAVAÇÃO E AMPLIFICAÇÃO DE ÁUDIO E VÍDEO                   25997
# ...

# %%
most_companies.head(10)
# Out:
# OI                17758
# SKY               14357
# CLARO             14090
# OI FIXO           11129
# SAMSUNG            9224
# VIVO               8528
# RICARDO ELETRO     8355
# MOTOROLA           7533
# TIM CELULAR        6506
# CCE                5672
# Name: strNomeFantasia, dtype: int64

# %%
most_desc.head(11)
# Out:
# Telefone ( Convencional, Celular, Interfone, Etc. )                121857
# Microcomputador / Produtos de Informática                           77934
# Telefonia Celular                                                   74551
# Banco comercial                                                     67781
# Telefonia Fixa ( Plano de Expansão / Compra e Venda / Locação )     67151
# Cartão de Crédito                                                   58796
# Televisão / Vídeo Cassete / Filmadora / Video-Laser                 48508
# Financeira                                                          44739
# Geladeira e Freezer                                                 38431
# Outros Contratos                                                    34141
# TV Por Assinatura ( Cabo, Satélite, Etc. )                          31354
# Name: DescricaoAssunto, dtype: int64
